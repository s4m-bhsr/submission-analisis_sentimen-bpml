# %%
pip install google_play_scraper
# Out:
# Requirement already satisfied: google_play_scraper in /usr/local/lib/python3.11/dist-packages (1.2.7)

# %%
from google_play_scraper import app, Sort, reviews

import pandas as pd

# %% [markdown]
# #Scrapping Data dari Play Store

# %%
result = reviews(
    'id.bmri.livin',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=20000, # defaults to 100
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %%
df = pd.DataFrame(result[0])
df.to_csv('ulasan_livin.csv', index=False)
print("Hasil Scraping berhasil disimpan")
# Out:
# Hasil Scraping berhasil disimpan

# %%
df.head()
# Out:
#                                reviewId         userName  \
# 0  64efb6b9-adf3-41b6-9699-11b1511ad12d  Pengguna Google
# 1  da619ef4-3db9-4b4c-b294-75c51baa8265  Pengguna Google
# 2  bad7f93d-5b71-4462-976c-9de9655a6077  Pengguna Google
# 3  f28ae28b-7f95-4910-b67d-4ab286a370b9  Pengguna Google
# 4  a337b44f-e3c0-4773-bb66-89d144c05ce1  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0           aplikasi kadang error tidak bisa di buka      2              0
# 1  kenapa saya gk bisa buka mbeking saya setiap b...      3              0
# 2                                              RIBET      1              0
# 3                                      keren mandiri      5              0
# 4  ulangi pembuatan password, verifikasi wajah ga...      1              0
#
#   reviewCreatedVersion                  at  \
# 0                2.2.0 2025-04-13 04:48:06
# 1                2.2.0 2025-04-13 04:41:47
# 2                2.2.0 2025-04-13 03:42:16
# 3                2.2.0 2025-04-13 03:16:28
# 4                2.2.0 2025-04-13 01:59:33
#
#                                         replyContent           repliedAt  \
# 0  Halo Sahabat @herman samarinda, mohon maaf ata... 2025-04-13 04:52:14
# 1  Halo Sahabat @Bagus Azis, mohon maaf atas keti... 2025-04-13 04:49:25
# 2  Halo Sahabat @yayasan Jam'iyyatul muta'alimin,... 2025-04-13 04:18:11
# 3  Halo Sahabat @ADAM rijaldi, terima kasih atas ... 2025-04-13 03:19:16
# 4  Halo Sahabat @Abdul Karim, mohon maaf atas\nke... 2025-04-13 03:27:30
#
#   appVersion
# 0      2.2.0
# 1      2.2.0
# 2      2.2.0
# 3      2.2.0
# 4      2.2.0
